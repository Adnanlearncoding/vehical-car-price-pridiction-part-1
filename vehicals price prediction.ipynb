# %% [markdown]
# ## Steps

# %%
#import libraries
#import dataset
#build the model/test
#start making prediction

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_price=pd.read_csv(r"C:\Users\Ali Mir\Desktop\ML models\archive (1).zip")

# %%
car_price
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# deviding our dataset into training and testing 
train_data,test_data= train_test_split( car_price, test_size=0.25, random_state=0)

# %%
train_data
# Out:
#                                          name  year  selling_price  km_driven  \
# 4313                        Hyundai i10 Magna  2012         267000      40000
# 5178       Mercedes-Benz New C-Class 200 K AT  2007         500000     120000
# 758                        Hyundai EON D Lite  2013         200000      80000
# 7117  Chevrolet Tavera Neo 3 LT 9 Seats BSIII  2016         900000     100000
# 2606                         Maruti Swift VDI  2013         375000      77000
# ...                                       ...   ...            ...        ...
# 4931    Tata Manza Aura (ABS) Quadrajet BS IV  2012         300000      70000
# 3264                     Ford Figo Diesel EXI  2012         220000     100000
# 1653                Hyundai i10 Sportz Option  2009         170000      90000
# 2607         Volkswagen Vento Diesel Highline  2012         375000      90000
# 2732                   Hyundai i10 Magna 1.1L  2012         225000     110000
#
# ...

# %%
car_price.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
#filling missing value and dropping useless columns
#dropping useless columns
car_price.drop(['torque','owner'],inplace=True,axis=1)

# %%
car_price
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
#filling missing values or fillna method
car_price.interpolate()
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
#x axis always in double brackets
x = car_price[['name','year','selling_price','km_driven','fuel','seller_type','transmission','mileage','engine','max_power','seats']]

# %%
y =car_price['selling_price'] #target variable or dependent variable

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train
# Out:
#                                    name  year  selling_price  km_driven  \
# 2246          Chevrolet Sail 1.2 LS ABS  2015         350000      50000
# 2095  Chevrolet Optra Magnum 2.0 LT BS3  2008         225000     120000
# 3290            Hyundai Grand i10 Magna  2014         370000      60000
# 6868                Maruti Alto 800 VXI  2020         360000       5000
# 6895             Mahindra XUV500 W9 2WD  2018        1350000      40000
# ...                                 ...   ...            ...        ...
# 7935                      Maruti 800 AC  1999          40000     100000
# 5192             Hyundai i20 Active 1.4  2016         580000     152000
# 3980               Hyundai EON Era Plus  2013         190000      70000
# 235                     Maruti Ritz LDi  2010         250000     110000
# 5157            Maruti Baleno Delta 1.2  2016         480000      65755
#
#         fuel seller_type transmission     mileage   engine  max_power  seats
# ...

# %%
len(y_test)
# Out:
# 2439

# %%
from sklearn.linear_model import LinearRegression
reg_model=LinearRegression()

# %%
#now fit our model 
reg_model.fit(x_train,y_train)
#it shows error beacuse we have some string in our data so we will change it in next step by binary numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ALIMIR~1\AppData\Local\Temp/ipykernel_460/3701953327.py in <module>
#       1 #now fit our model
# ----> 2 reg_model.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
